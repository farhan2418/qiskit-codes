# %%
import rustworkx as rx
import numpy as np
import matplotlib.pyplot as plt
from rustworkx.visualization import mpl_draw as draw_graph
from qiskit_ibm_runtime import QiskitRuntimeService
from scipy.optimize import minimize

from qiskit import QuantumCircuit
from qiskit.providers.fake_provider import GenericBackendV2
from qiskit.quantum_info import SparsePauliOp, Statevector, DensityMatrix, Operator
from qiskit.circuit.library import QAOAAnsatz
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.visualization import plot_histogram
from qiskit.transpiler import Layout

from qiskit_ibm_runtime import (
    Session,
    EstimatorV2 as Estimator,
    SamplerV2 as Sampler,
    EstimatorOptions,
)
from qiskit_ibm_runtime.debug_tools import Neat
from qiskit_aer import AerSimulator

service = QiskitRuntimeService()

# from utils import zne_method, plot_zne, plot_backend_errors_and_counts
# Out:
# C:\Users\kafar\AppData\Local\Temp\ipykernel_7372\2037032326.py:25: DeprecationWarning: The "ibm_quantum" channel option is deprecated and will be sunset on 1 July. After this date, "ibm_cloud", "ibm_quantum_platform", and "local" will be the only valid channels. Open Plan users should migrate now.  All other users should review the migration guide (https://quantum.cloud.ibm.com/docs/migration-guides/classic-iqp-to-cloud-iqp)to learn when to migrate.
#   service = QiskitRuntimeService()
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\kafar\OneDrive\Documents\QT 608 - Quantum Computing\Qiskit\Qworld\qisvenv\Lib\site-packages\qiskit_ibm_runtime\api\session.py:328, in RetrySession.request(self, method, url, bare, **kwargs)
#     327     response = super().request(method, final_url, headers=headers, **kwargs)
# --> 328     response.raise_for_status()
#     329 except RequestException as ex:
#     330     # Wrap the requests exceptions into a IBM Q custom one, for
#     331     # compatibility.
#
# File c:\Users\kafar\OneDrive\Documents\QT 608 - Quantum Computing\Qiskit\Qworld\qisvenv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://auth.quantum.ibm.com/api/users/loginWithToken
#
# The above exception was the direct cause of the following exception:
#
# IBMNotAuthorizedError                     Traceback (most recent call last)
# Cell In[1], line 25
#      22 from qiskit_ibm_runtime.debug_tools import Neat
#      23 from qiskit_aer import AerSimulator
# ---> 25 service = QiskitRuntimeService()
#      27 # from utils import zne_method, plot_zne, plot_backend_errors_and_counts
#
# File c:\Users\kafar\OneDrive\Documents\QT 608 - Quantum Computing\Qiskit\Qworld\qisvenv\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:215, in QiskitRuntimeService.__init__(self, channel, token, url, filename, name, instance, proxies, verify, private_endpoint, url_resolver, region, plans_preference)
#     204 else:
#     205     warnings.warn(
#     206         'The "ibm_quantum" channel option is deprecated and will be sunset on 1 July. '
#     207         'After this date, "ibm_cloud", "ibm_quantum_platform", and "local" will be the '
#    (...)    213         stacklevel=2,
#     214     )
# --> 215     auth_client = self._authenticate_ibm_quantum_account(self._client_params)
#     216     # Update client parameters to use authenticated values.
#     217     self._client_params.url = auth_client.current_service_urls()["services"]["runtime"]
#
# File c:\Users\kafar\OneDrive\Documents\QT 608 - Quantum Computing\Qiskit\Qworld\qisvenv\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:412, in QiskitRuntimeService._authenticate_ibm_quantum_account(self, client_params)
#     405 if not version_info["new_api"] or "api-auth" not in version_info:
#     406     raise IBMInputValueError(
#     407         "The URL specified ({}) is not an IBM Quantum authentication URL. "
#     408         "Valid authentication URL: {}.".format(
#     409             client_params.url, QISKIT_IBM_RUNTIME_API_URL
#     410         )
#     411     )
# --> 412 auth_client = AuthClient(client_params)
#     413 service_urls = auth_client.current_service_urls()
#     414 if not service_urls.get("services", {}).get(SERVICE_NAME):
#
# File c:\Users\kafar\OneDrive\Documents\QT 608 - Quantum Computing\Qiskit\Qworld\qisvenv\Lib\site-packages\qiskit_ibm_runtime\api\clients\auth.py:39, in AuthClient.__init__(self, client_params)
#      36 self._service_urls = {}  # type: ignore[var-annotated]
#      38 self.auth_api = Api(RetrySession(self.auth_url, **client_params.connection_parameters()))
# ---> 39 self.base_api = self._init_service_clients(**client_params.connection_parameters())
#
# File c:\Users\kafar\OneDrive\Documents\QT 608 - Quantum Computing\Qiskit\Qworld\qisvenv\Lib\site-packages\qiskit_ibm_runtime\api\clients\auth.py:51, in AuthClient._init_service_clients(self, **request_kwargs)
#      42 """Initialize the clients used for communicating with the API.
#      43
#      44 Args:
#    (...)     48     Client for the API server.
#      49 """
#      50 # Request an access token.
# ---> 51 self.access_token = self._request_access_token()
#      52 self.auth_api.session.auth = QuantumAuth(access_token=self.access_token)
#      53 self._service_urls = self.user_urls()
#
# File c:\Users\kafar\OneDrive\Documents\QT 608 - Quantum Computing\Qiskit\Qworld\qisvenv\Lib\site-packages\qiskit_ibm_runtime\api\clients\auth.py:77, in AuthClient._request_access_token(self)
#      67 """Request a new access token from the API authentication service.
#      68
#      69 Returns:
#    (...)     74     RequestsApiError: If the request failed.
#      75 """
#      76 try:
# ---> 77     response = self.auth_api.login(self.api_token)
#      78     return response["id"]
#      79 except RequestsApiError as ex:
#      80     # Get the original exception that raised.
#
# File c:\Users\kafar\OneDrive\Documents\QT 608 - Quantum Computing\Qiskit\Qworld\qisvenv\Lib\site-packages\qiskit_ibm_runtime\api\rest\root.py:93, in Api.login(self, api_token)
#      84 """Login with token.
#      85
#      86 Args:
#    (...)     90     JSON response.
#      91 """
#      92 url = self.get_url("login")
# ---> 93 return self.session.post(
#      94     url, json={"apiToken": api_token}, headers=self._HEADER_JSON_CONTENT
#      95 ).json()
#
# File c:\Users\kafar\OneDrive\Documents\QT 608 - Quantum Computing\Qiskit\Qworld\qisvenv\Lib\site-packages\requests\sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)    634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File c:\Users\kafar\OneDrive\Documents\QT 608 - Quantum Computing\Qiskit\Qworld\qisvenv\Lib\site-packages\qiskit_ibm_runtime\api\session.py:349, in RetrySession.request(self, method, url, bare, **kwargs)
#     347         message += f". {ex.response.text}"
#     348 if status_code == 401:
# --> 349     raise IBMNotAuthorizedError(message) from ex
#     350 if status_code == 503:  # Planned maintenance outage
#     351     raise RequestsApiError(
#     352         "Unexpected response received from server. Please check if the service "
#     353         "is in maintenance mode "
#     354         f"https://docs.quantum.ibm.com/announcements/service-alerts {message}"
#     355     )
#
# IBMNotAuthorizedError: '401 Client Error: Unauthorized for url: https://auth.quantum.ibm.com/api/users/loginWithToken. This version of platform has been sunset. Create an account or sign in to the upgraded IBM Quantum Platform at https://quantum.cloud.ibm.com, Error code: 3447.'

# %%
# We define the seed
seed = 43
# We define the number of nodes:
n = 5
# We define the graph
graph = rx.PyGraph()
graph.add_nodes_from(np.arange(0, n, 1))
generic_backend = GenericBackendV2(n, seed=seed)
weights = 1
# We make it explicitly asymmetrical to have a smaller set of solutions
graph.add_edges_from([(edge[0], edge[1], weights) for edge in generic_backend.coupling_map][:-1])
draw_graph(graph, node_size=200, with_labels=True, width=1)
# Out:
# EdgeList[(0, 1), (1, 0), (0, 2), (2, 0), (0, 3), (3, 0), (0, 4), (4, 0), (1, 2), (2, 1), (1, 3), (3, 1), (1, 4), (4, 1), (2, 3), (3, 2), (2, 4), (4, 2), (3, 4)]
